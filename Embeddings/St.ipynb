# %%
# pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
data=open('data.txt',encoding='utf-8').read()
data
# Out:
# 'Artificial Intelligence@ (AI) is one of the fastest-growing fields in technology. It enables machines to simulate human intelligence and solve complex problems. AI includes several domains such as Machine Learning, Deep Learning, Natural Language Processing, and Computer Vision.\n\nMachine Learning allows computers$ to learn from historical data and make predictions. It can be divided into supervised learning, unsupervised learning, and reinforcement learning. Supervised learning uses labeled data🥱, while unsupervised learning finds hidden patterns in unlabeled data.\n\nDeep Learning is based on artificial neural! networks. It has revolutionized image recognition, speech processing, and language translation. Popular frameworks for Deep Learning include TensorFlow and PyTorch.😎😎\n\nNatural Language Processing (NLP) enables computers to understand and generate human language. NLP applications include chatbots, sentiment analysis, machine translation, and text summarization. Tokenization, stemming, lemmatization, and chunking are common NLP preprocessing techniques.😍\n\nComputer Vision& focuses on enabling machines to interpret visual information. It is used in facial recognition, autonomous vehicles, medical imaging, and surveillance systems. Image classification, object detection, and image segmentation are common computer vision tasks.🤑\n\nGenerative AI is an advanced area of @AI that creates new content such as text, images, music, and videos. Large Language Models (LLMs) like GPT are examples of Generative AI systems. These models are trained on massive datasets and can answer questions, write code, summarize documents, and assist users in many tasks.'

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

# %%
chunks=splitter.split_text(data)    #list of strings(chunks)
print(chunks,type(chunks),type(chunks[0]))
# Out:
# ['Artificial Intelligence@ (AI) is one of the fastest-growing fields in technology. It enables', 'It enables machines to simulate human intelligence and solve complex problems. AI includes several', 'AI includes several domains such as Machine Learning, Deep Learning, Natural Language Processing,', 'Processing, and Computer Vision.', 'Machine Learning allows computers$ to learn from historical data and make predictions. It can be', 'It can be divided into supervised learning, unsupervised learning, and reinforcement learning.', 'learning. Supervised learning uses labeled data🥱, while unsupervised learning finds hidden patterns', 'hidden patterns in unlabeled data.', 'Deep Learning is based on artificial neural! networks. It has revolutionized image recognition,', 'image recognition, speech processing, and language translation. Popular frameworks for Deep', 'frameworks for Deep Learning include TensorFlow and PyTorch.😎😎', 'Natural Language Processing (NLP) enables computers to understand and generate human language. NLP', 'human language. NLP applications include chatbots, sentiment analysis, machine translation, and', 'translation, and text summarization. Tokenization, stemming, lemmatization, and chunking are common', 'chunking are common NLP preprocessing techniques.😍', 'Computer Vision& focuses on enabling machines to interpret visual information. It is used in facial', 'is used in facial recognition, autonomous vehicles, medical imaging, and surveillance systems.', 'systems. Image classification, object detection, and image segmentation are common computer vision', 'computer vision tasks.🤑', 'Generative AI is an advanced area of @AI that creates new content such as text, images, music, and', 'images, music, and videos. Large Language Models (LLMs) like GPT are examples of Generative AI', 'of Generative AI systems. These models are trained on massive datasets and can answer questions,', 'answer questions, write code, summarize documents, and assist users in many tasks.'] <class 'list'> <class 'str'>

# %%
embeddings=SentenceTransformer(
    model_name_or_path='sentence-transformers/all-miniLM-L6-V2'
)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\DELL\.cache\huggingface\hub\models--sentence-transformers--all-miniLM-L6-V2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3809.61it/s]

# %%
embeddings.encode(chunks)
# Out:
# array([[-2.00887416e-02, -2.76567135e-02, -1.69468131e-02, ...,
#          1.77506246e-02,  6.91976547e-02, -5.31557808e-03],
#        [-4.58705351e-02, -6.07228512e-03,  2.83023734e-02, ...,
#          9.47058797e-02,  4.57814969e-02, -6.78860918e-02],
#        [ 1.29789235e-02, -1.17299430e-01,  2.43720785e-02, ...,
#          5.39841391e-02,  7.58975223e-02, -3.37987542e-02],
#        ...,
#        [-3.05300597e-02, -1.23650193e-01,  5.68514839e-02, ...,
#          8.01881254e-02,  8.07874743e-03, -2.97682285e-02],
#        [-6.95530176e-02, -7.87895843e-02,  6.25432134e-02, ...,
#          2.10078359e-02,  1.23800989e-02, -1.78479645e-02],
#        [-6.99019711e-03,  2.74497140e-02, -3.67241919e-05, ...,
#          5.48602007e-02, -4.25324030e-02,  2.08933046e-03]],
#       shape=(23, 384), dtype=float32)
