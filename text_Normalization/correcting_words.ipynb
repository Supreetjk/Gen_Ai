# %%
pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 834.7 kB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.1 MB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 1.1 MB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.1 MB/s eta 0:00:01
# ...

# %%
from textblob import TextBlob

# %%
text='corting the wods for txt normalization'
text1='i havv corret the wods for txtt normaliation'

corrected_words=TextBlob(text1).correct()
print(corrected_words,type(corrected_words))
# Out:
# i have correct the words for txt normaliation <class 'textblob.blob.TextBlob'>
