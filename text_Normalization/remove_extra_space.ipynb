# %%
with open('data.txt','r')as file:
    data=file.read()
    words=data.split()
    data=' '.join(words)

# %%
print(data)
# Out:
# ðŸ˜Žpython is @high level# language. i love money$, money loves me$ðŸ’² hiiii baby how are youuuuuuu

# %%
s='open    file                '
print(s.split())
# Out:
# ['open', 'file']
