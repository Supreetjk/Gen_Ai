# %%
from nltk.stem import PorterStemmer

# %%
stemmer=PorterStemmer()

# %%
words=[ "running",

"runner",

"runs",

"played",

"playing",

"plays",

"happier",

"happiness",

"studies",

"studying",

"studied",

"connected",

"connecting",

"playing",

"plays",

"happier",

"happiness",

"studies",

"studying",

"studied",

"connected",

"connecting",

"connection",

"better",

"best",

"dogs",

"flying",

"flies", 'a', 'the'
]
for word in words:
    print(f'{word}-->{stemmer.stem(word)}')

#its only removing the suffix and giving the correct rootform
# Out:
# running-->run
# runner-->runner
# runs-->run
# played-->play
# playing-->play
# plays-->play
# happier-->happier
# happiness-->happi
# studies-->studi
# studying-->studi
# studied-->studi
# connected-->connect
# connecting-->connect
# playing-->play
# plays-->play
# happier-->happier
# happiness-->happi
# studies-->studi
# studying-->studi
# studied-->studi
# connected-->connect
# connecting-->connect
# connection-->connect
# better-->better
# best-->best
# dogs-->dog
# flying-->fli
# flies-->fli
# a-->a
# the-->the

# %%
from nltk.stem import SnowballStemmer
Snowball_Stemmer=SnowballStemmer('english',ignore_stopwords=False)

# %%
snowball_words=[
"running",

"runner",

"runs",

"played",

"playing",

"plays",

"happier",

"happiness",

"studies",

"studying",

"studied",

"connected",

"connecting",

"playing",

"plays",

"happier",

"happiness",

"studies",

"studying",

"studied",

"connected",

"connecting",

"connection",

"better",

"best",

"dogs",

"flying",

"flies", 'a', 'the'
]

for word in words:
    print(f"{word}--->{Snowball_Stemmer.stem(word)}")
# Out:
# running--->run
# runner--->runner
# runs--->run
# played--->play
# playing--->play
# plays--->play
# happier--->happier
# happiness--->happi
# studies--->studi
# studying--->studi
# studied--->studi
# connected--->connect
# connecting--->connect
# playing--->play
# plays--->play
# happier--->happier
# happiness--->happi
# studies--->studi
# studying--->studi
# studied--->studi
# connected--->connect
# connecting--->connect
# connection--->connect
# better--->better
# best--->best
# dogs--->dog
# flying--->fli
# flies--->fli
# a--->a
# the--->the

# %%
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# %%
stop_words=stopwords.words('english')
# stop_words
Snowball_Stemmer=SnowballStemmer('english',ignore_stopwords=True)
Snowball_Stemmer.stopwords=stop_words
Snowball_Stemmer.stopwords
for word in snowball_words:
    print(word,Snowball_Stemmer.stem(word))
# Out:
# running run
# runner runner
# runs run
# played play
# playing play
# plays play
# happier happier
# happiness happi
# studies studi
# studying studi
# studied studi
# connected connect
# connecting connect
# playing play
# plays play
# happier happier
# happiness happi
# studies studi
# studying studi
# studied studi
# connected connect
# connecting connect
# connection connect
# better better
# best best
# dogs dog
# flying fli
# flies fli
# a a
# the the

# %%
Snowball_Stemmer.stemmer
