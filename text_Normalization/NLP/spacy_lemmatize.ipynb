# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.8.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.33.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (83.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.0)
# Requirement already satisfied: httpx>=0.24.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      ------- -------------------------------- 2.4/12.8 MB 10.0 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 13.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 14.7 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 15.0 MB/s  0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

tokens=nlp('''Apply the Pipeline To some text. 
           The text can Span multiple sentences, 
           and can contain Arbitrary Whitespace. 
           Alignment into the Original string is Preserved. ''')
print(type(tokens),tokens)
# Out:
# <class 'spacy.tokens.doc.Doc'> Apply the Pipeline To some text.
#            The text can Span multiple sentences,
#            and can contain Arbitrary Whitespace.
#            Alignment into the Original string is Preserved.

# %%
lemmatize_tokens=[token.lemma_ for token in tokens if not token.is_stop]
# for token in tokens:
#     # print(token,type(token))
#     print(token.lemma_,token.is_stop)
print(lemmatize_tokens)
print(" ".join(lemmatize_tokens))
# Out:
# ['apply', 'Pipeline', 'text', '.', '\n           ', 'text', 'span', 'multiple', 'sentence', ',', '\n           ', 'contain', 'Arbitrary', 'Whitespace', '.', '\n           ', 'alignment', 'original', 'string', 'preserve', '.']
# apply Pipeline text .
#             text span multiple sentence ,
#             contain Arbitrary Whitespace .
#             alignment original string preserve .

# %%
text='''Shivu has planned for trip to Dubai with https://www.ixigo.com/ using my gmail supreetjkadakol@gmail.com to get 50% offer.The flight is on 15/07/2026 and the price is 1,00,000. he is specilized in SoftwareDevleopment. If possible he will get placed in Google'''
tokens=nlp(text)

# %%
print(type(tokens.ents))
tokens.ents
# Out:
# <class 'tuple'>
# (Shivu, Dubai, 15/07/2026, 1,00,000)

# %%
for token in tokens:
    print(token.pos_,token.tag_)
# Out:
# PROPN NNP
# AUX VBZ
# VERB VBN
# ADP IN
# NOUN NN
# ADP IN
# PROPN NNP
# PUNCT .
# DET DT
# NOUN NN
# AUX VBZ
# ADP IN
# NUM CD
# CCONJ CC
# DET DT
# NOUN NN
# AUX VBZ
# NUM CD

# %%
for token in tokens:
    print(token.lemma_,token.pos_,token.ent_type_)
# Out:
# Shivu PROPN PERSON
# have AUX
# plan VERB
# for ADP
# trip NOUN
# to ADP
# Dubai PROPN GPE
# with ADP
# https://www.ixigo.com/ NOUN
# use VERB
# my PRON
# gmail NOUN
# supreetjkadakol@gmail.com NOUN
# to PART
# get VERB
# 50 NUM PERCENT
# % NOUN PERCENT
# offer NOUN
# . PUNCT
# the DET
# flight NOUN
# be AUX
# on ADP
# 15/07/2026 NUM DATE
# and CCONJ
# the DET
# price NOUN
# be AUX
# 1,00,000 NUM CARDINAL
# . PUNCT
# he PRON
# be AUX
# specilize VERB
# in ADP
# SoftwareDevleopment PROPN ORG
# . PUNCT
# if SCONJ
# possible ADJ
# he PRON
# will AUX
# get AUX
# place VERB
# in ADP
# Google PROPN ORG

# %%
for ent in tokens.ents:
    print(ent.text,ent.label_)
# Out:
# Shivu PERSON
# Dubai GPE
# 50% PERCENT
# 15/07/2026 DATE
# 1,00,000 CARDINAL
# SoftwareDevleopment ORG
# Google ORG
