# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
with open(r"data.txt") as file:
    data=file.read()

# %%
data
# Out:
# 'ðŸ˜Žpython is   @high level# language.\n i love     money$, \n money loves       me$ðŸ’²\n\nhiiii baby         how are youuuuuuu\n\n\n'

# %%
from nltk.tokenize import word_tokenize
tokens=word_tokenize(data)

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
updated_tokens=[]
for word in tokens:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)
# Out:
# ['ðŸ˜Žpython', '@', 'high', 'level', '#', 'language', '.', 'love', 'money', '$', ',', 'money', 'loves', '$', 'ðŸ', '’', '²', 'hiiii', 'baby', 'youuuuuuu']

# %%
nlp_sentence=[

"The cat sat quietly on the windowsill, watching the rain.",

"Natural language processing helps computers understand human com unication.",

"Can you believe how quickly technology is evolving these days!",

"She bought fresh vegetables, fruits, and bread from the market.",

"Although tired, he continued working late into the night.",

"The movie was exciting, but the ending felt disappointing.",

"Please call me tomorrow morning before the meeting starts.",

"The movie was exciting, but the ending felt disappointing.",

"Please call me tomorrow morning before the meeting starts.",

"Data scientists often clean messy datasets before running models." "Wow, that was the best performance Ive ever seen!",

"If it rains tomorrow, we will cancel the picnic."

]

# %%
from nltk.tokenize import sent_tokenize
sent_tokens=stopwords.words('english')

# %%
updated_sentences=[]
for sentence in nlp_sentence:
    words=word_tokenize(sentence)
    filtered_words=[word for word in words if word.lower() not in stop_words]
    updated_sentences.append("".join(filtered_words))

# %%
for sentence in updated_sentences:
    print(sentence)
# Out:
# catsatquietlywindowsill,watchingrain.
# Naturallanguageprocessinghelpscomputersunderstandhumancomunication.
# believequicklytechnologyevolvingdays!
# boughtfreshvegetables,fruits,breadmarket.
# Althoughtired,continuedworkinglatenight.
# movieexciting,endingfeltdisappointing.
# Pleasecalltomorrowmorningmeetingstarts.
# movieexciting,endingfeltdisappointing.
# Pleasecalltomorrowmorningmeetingstarts.
# Datascientistsoftencleanmessydatasetsrunningmodels.Wow,bestperformanceIveeverseen!
# rainstomorrow,cancelpicnic.

# %%
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...
