# %%
pip install emoji
# Out:
# ...
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------- ----- 524.3/608.4 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 608.4/608.4 kB 1.8 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

# %%
s='Hello, I am a 🤖. I love to play with emojis!😄🎉'
emoji.replace_emoji(s,'')
# Out:
# 'Hello, I am a . I love to play with emojis!'

# %%
s='Hello🤞, I am a 🤖. I love to play with 🤑👻.I Love 🐼💋'
emoji.demojize(s)
# Out:
# 'Hello:crossed_fingers:, I am a :robot:. I love to play with :money-mouth_face::ghost:.I Love :panda::kiss_mark:'
